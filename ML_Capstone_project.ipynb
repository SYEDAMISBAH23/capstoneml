# %% [markdown]
# **Capstone Project**
#
# #Employee Salary Prediction -
#
# Linear Regression
#
# Support Vector Regression
#
# Random Forest Regression
#
# Deployment-streamlit

# %%
#step 1 : load the dataset
import pandas as pd
df=pd.read_csv("C:/Users/misba/Desktop/employee_attrition_data.csv")
df
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0              0   27    Male    Marketing        Manager                 9
# 1              1   53  Female        Sales       Engineer                10
# 2              2   59  Female    Marketing        Analyst                 8
# 3              3   42  Female  Engineering        Manager                 1
# 4              4   44  Female        Sales       Engineer                10
# ..           ...  ...     ...          ...            ...               ...
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
# ...

# %%
df.head(10)
# Out:
#    Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 0            0   27    Male    Marketing        Manager                 9
# 1            1   53  Female        Sales       Engineer                10
# 2            2   59  Female    Marketing        Analyst                 8
# 3            3   42  Female  Engineering        Manager                 1
# 4            4   44  Female        Sales       Engineer                10
# 5            5   47    Male        Sales  HR Specialist                10
# 6            6   58    Male    Marketing  HR Specialist                 5
# 7            7   57  Female        Sales        Analyst                 8
# 8            8   34  Female      Finance     Accountant                 6
# 9            9   57  Female    Marketing       Engineer                 7
#
#    Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# 0            0.586251                    151                      0   60132
# ...

# %%
df.tail(10)
# Out:
#      Employee_ID  Age  Gender   Department      Job_Title  Years_at_Company  \
# 990          990   36  Female  Engineering     Accountant                 9
# 991          991   47    Male    Marketing        Manager                 2
# 992          992   46  Female           HR        Analyst                 8
# 993          993   47  Female           HR        Analyst                 5
# 994          994   47    Male    Marketing  HR Specialist                 2
# 995          995   39  Female           HR  HR Specialist                 3
# 996          996   50    Male  Engineering        Manager                 1
# 997          997   52    Male  Engineering        Analyst                 3
# 998          998   37  Female           HR  HR Specialist                 2
# 999          999   59    Male        Sales  HR Specialist                 1
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Age', 'Gender', 'Department', 'Job_Title',
#        'Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours',
#        'Promotion_Last_5Years', 'Salary', 'Attrition'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Age                    1000 non-null   int64
#  2   Gender                 1000 non-null   object
#  3   Department             1000 non-null   object
#  4   Job_Title              1000 non-null   object
#  5   Years_at_Company       1000 non-null   int64
#  6   Satisfaction_Level     1000 non-null   float64
#  7   Average_Monthly_Hours  1000 non-null   int64
#  8   Promotion_Last_5Years  1000 non-null   int64
#  9   Salary                 1000 non-null   int64
#  10  Attrition              1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
#step 3: check missing values
df.isna()
# Out:
#      Employee_ID    Age  Gender  Department  Job_Title  Years_at_Company  \
# 0          False  False   False       False      False             False
# 1          False  False   False       False      False             False
# 2          False  False   False       False      False             False
# 3          False  False   False       False      False             False
# 4          False  False   False       False      False             False
# ..           ...    ...     ...         ...        ...               ...
# 995        False  False   False       False      False             False
# 996        False  False   False       False      False             False
# 997        False  False   False       False      False             False
# 998        False  False   False       False      False             False
# 999        False  False   False       False      False             False
#
#      Satisfaction_Level  Average_Monthly_Hours  Promotion_Last_5Years  Salary  \
# ...

# %%
df.isna().sum()
# Out:
# Employee_ID              0
# Age                      0
# Gender                   0
# Department               0
# Job_Title                0
# Years_at_Company         0
# Satisfaction_Level       0
# Average_Monthly_Hours    0
# Promotion_Last_5Years    0
# Salary                   0
# Attrition                0
# dtype: int64

# %%
#check for duplicated values
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#step5: remove unwanted columns
df.drop(columns='Employee_ID',inplace=True)

# %%
# !pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\misba\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt

# %%
df["Gender"].value_counts().plot(kind="pie",color={'red','yellow'})
plt.ylabel("")
plt.title("Gender count of employees ")
plt.show()

# %%
df["Department"].value_counts().plot(kind="bar",color={'violet','orange'})
plt.ylabel("")
plt.title("department count of employees ")
plt.show()

# %%
df["Years_at_Company"].value_counts().plot(kind="bar",color={'cyan','navy'})
plt.ylabel("")
plt.title("Years_at_Company count of employees ")
plt.show()

# %%
df.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind="line",color='brown')
plt.title("Average Salary by Job Title ")
plt.xlabel("Job Title")
plt.ylabel("Average salary")
plt.show()

# %%
df.groupby("Job_Title")["Salary"].mean().sort_values(ascending=False).plot(kind="pie",color='brown')
plt.title("Average Salary by Job Title ")
plt.xlabel("Job Title")
plt.ylabel("Average salary")
plt.show()

# %%
df.groupby(["Department","Promotion_Last_5Years"])["Salary"].mean().reset_index()
# Out:
#     Department  Promotion_Last_5Years        Salary
# 0  Engineering                      0  65541.063636
# 1  Engineering                      1  62424.127660
# 2      Finance                      0  63390.145299
# 3      Finance                      1  62041.269663
# 4           HR                      0  63012.556701
# 5           HR                      1  65882.861702
# 6    Marketing                      0  65251.597826
# 7    Marketing                      1  66018.632653
# 8        Sales                      0  64295.846939
# 9        Sales                      1  67838.756757

# %%
df.head()
# Out:
#    Age  Gender   Department Job_Title  Years_at_Company  Satisfaction_Level  \
# 0   27    Male    Marketing   Manager                 9            0.586251
# 1   53  Female        Sales  Engineer                10            0.261161
# 2   59  Female    Marketing   Analyst                 8            0.304382
# 3   42  Female  Engineering   Manager                 1            0.480779
# 4   44  Female        Sales  Engineer                10            0.636244
#
#    Average_Monthly_Hours  Promotion_Last_5Years  Salary  Attrition
# 0                    151                      0   60132          0
# 1                    221                      1   79947          0
# 2                    184                      0   46958          1
# 3                    242                      0   40662          0
# 4                    229                      1   74307          0

# %%
df.describe()
# Out:
#                Age  Years_at_Company  Satisfaction_Level  \
# count  1000.000000       1000.000000         1000.000000
# mean     42.205000          5.605000            0.505995
# std      10.016452          2.822223            0.289797
# min      25.000000          1.000000            0.001376
# 25%      33.000000          3.000000            0.258866
# 50%      43.000000          6.000000            0.505675
# 75%      51.000000          8.000000            0.761135
# max      59.000000         10.000000            0.999979
#
#        Average_Monthly_Hours  Promotion_Last_5Years        Salary    Attrition
# count            1000.000000            1000.000000   1000.000000  1000.000000
# mean              199.493000               0.486000  64624.980000     0.495000
# std                29.631908               0.500054  20262.984333     0.500225
# min               150.000000               0.000000  30099.000000     0.000000
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Department', 'Job_Title', 'Years_at_Company',
#        'Satisfaction_Level', 'Average_Monthly_Hours', 'Promotion_Last_5Years',
#        'Salary', 'Attrition'],
#       dtype='object')

# %%
#split into features and target
x=df[["Years_at_Company","Satisfaction_Level","Average_Monthly_Hours"]]
y=df["Salary"]

# %%
# !pip install scikit-learn
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\misba\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x
# Out:
#      Years_at_Company  Satisfaction_Level  Average_Monthly_Hours
# 0                   9            0.586251                    151
# 1                  10            0.261161                    221
# 2                   8            0.304382                    184
# 3                   1            0.480779                    242
# 4                  10            0.636244                    229
# ..                ...                 ...                    ...
# 995                 3            0.377435                    239
# 996                 1            0.431152                    154
# 997                 3            0.647102                    206
# 998                 2            0.304813                    241
# 999                 1            0.940510                    159
#
# [1000 rows x 3 columns]

# %%
y
# Out:
# 0      60132
# 1      79947
# 2      46958
# 3      40662
# 4      74307
#        ...
# 995    71403
# 996    30181
# 997    64143
# 998    74383
# 999    73220
# Name: Salary, Length: 1000, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_train
# Out:
# array([[-0.9143998 ,  0.38647326, -0.17633253],
#        [-0.56100857, -0.95914995,  0.09566752],
#        [-1.62118225, -1.02082305,  0.63966763],
#        ...,
#        [ 1.55933879,  0.90149189,  0.36766757],
#        [-0.20761735,  0.03697987, -1.36633277],
#        [-0.56100857,  0.55014033,  1.5236678 ]], shape=(800, 3))

# %%
import joblib
joblib.dump(scaler,"scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.49916511,  1.3263107 ,  0.40166758],
#        [ 1.20594756, -1.58402225, -0.89033268],
#        [ 1.55933879, -0.33306318, -0.0063325 ],
#        [ 1.55933879, -1.65636875, -1.09433272],
#        [-0.20761735, -0.47520719, -1.09433272],
#        [ 0.85255633,  0.97547749, -1.5023328 ],
#        [ 0.49916511, -0.34658733, -1.5023328 ],
#        [ 0.49916511,  0.91007203,  1.59166781],
#        [-0.20761735,  0.1687333 , -1.57033281],
#        [-0.20761735,  0.58166784,  1.55766781],
#        [ 0.85255633, -0.47502766,  0.57166761],
#        [ 0.14577388,  1.20877527, -0.5163326 ],
#        [ 0.85255633,  0.45973721, -0.55033261],
#        [ 0.49916511, -0.98807837,  1.69366783],
#        [ 0.49916511,  0.15919169,  0.12966753],
#        [-1.62118225,  0.33837422, -1.46833279],
#        [-0.9143998 , -1.59380604,  0.91166768],
#        [ 1.20594756,  1.38447116,  0.97966769],
#        [ 0.49916511,  0.45412516, -1.19633274],
#        [-1.26779103, -0.40458339,  0.97966769],
# ...

# %%
import numpy as np
from sklearn.metrics import mean_squared_error,mean_absolute_error
def results(predictions):
  print("mean absolute error on model is{}",format(mean_absolute_error(y_test,predictions)))
  print("root mean squared error on model is{}",format(np.sqrt(mean_squared_error(y_test,predictions))))
  print("mean squared error on model is{}",format(mean_squared_error(y_test,predictions)))

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predictionlr=lr.predict(x_test)

# %%
results(predictionlr)
# Out:
# mean absolute error on model is{} 18474.128739359985
# root mean squared error on model is{} 21146.089661684655
# mean squared error on model is{} 447157107.9800066

# %% [markdown]
# **Support Vector Equation**

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
svrmodel=SVR()

# %%
param_gridsvr={
    'C':[0.1,1,10],
    'epsilon':[0.1,0.2,0.5],
    'kernel':['linear','poly','rbf'],
    'degree':[2,3,4]
}
gridsvr=GridSearchCV(svrmodel,param_gridsvr)
gridsvr.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=SVR(),
#              param_grid={'C': [0.1, 1, 10], 'degree': [2, 3, 4],
#                          'epsilon': [0.1, 0.2, 0.5],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
gridsvr.best_params_
# Out:
# {'C': 10, 'degree': 2, 'epsilon': 0.5, 'kernel': 'linear'}

# %%
predictionssvr=gridsvr.predict(x_test)

# %%
results(predictionssvr)
# Out:
# mean absolute error on model is{} 18451.298447605324
# root mean squared error on model is{} 21101.9214567366
# mean squared error on model is{} 445291089.16628057

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'c:\Users\misba\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))

# Select only numeric columns for correlation calculation
numeric_df = df.select_dtypes(include=['number'])

sns.heatmap(numeric_df.corr(),annot=True,cmap='plasma',fmt='.2f',linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rfmodel=RandomForestRegressor()

# %%
param_gridrfr={
    'n_estimators':[2,3,4,5,6],
    'max_depth':[5,10,15]
}

# %%
gridrfr=GridSearchCV(estimator=rfmodel,param_grid=param_gridrfr,cv=5)
gridrfr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 3}

# %%
predictionofrfr=gridrfr.predict(x_test)

# %%
results(predictionofrfr)
# Out:
# mean absolute error on model is{} 18633.776670521493
# root mean squared error on model is{} 21740.76469016243
# mean squared error on model is{} 472660849.31301343

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Example: Load your data
# df = pd.read_csv("your_file.csv")
# X = df.drop("target_column", axis=1)
# y = df["target_column"]

# Assuming you already have X and y
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Models
models = {
    "Linear Regression": LinearRegression(),
    "Random Forest": RandomForestRegressor(random_state=42),
    "SVM": SVR()
}

rmse_scores = {}

# Train and evaluate
for name, model in models.items():
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    rmse_scores[name] = rmse
    print(f"{name} RMSE: {rmse:.2f}")

# Plot RMSE comparison
plt.figure(figsize=(8, 5))
plt.bar(rmse_scores.keys(), rmse_scores.values(), color=['teal', 'salmon', 'lightgreen'])
plt.title("RMSE Comparison of Models")
plt.ylabel("Root Mean Squared Error")
plt.xlabel("Models")
plt.tight_layout()
plt.show()
# Out:
# Linear Regression RMSE: 21146.09
# Random Forest RMSE: 22999.45
# SVM RMSE: 21098.66

# %%
gridrfr
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6]})

# %%
joblib.dump(gridrfr,"model.pkl")
# Out:
# ['model.pkl']

# %%
x.columns
# Out:
# Index(['Years_at_Company', 'Satisfaction_Level', 'Average_Monthly_Hours'], dtype='object')

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

# RMSE for Linear Regression
rmse_lr = np.sqrt(mean_squared_error(y_test, predictionlr))
print("Linear Regression RMSE:", rmse_lr)

# RMSE for Random Forest
rmse_rf = np.sqrt(mean_squared_error(y_test,predictionofrfr))
print("Random Forest RMSE:", rmse_rf)

# RMSE for Support Vector Regressor
rmse_svr = np.sqrt(mean_squared_error(y_test, predictionssvr))
print("SVM RMSE:", rmse_svr)
# Out:
# Linear Regression RMSE: 21146.089661684655
# Random Forest RMSE: 21740.76469016243
# SVM RMSE: 21101.9214567366
